# %% [markdown]
# <a href="https://colab.research.google.com/github/Saauraav246/Saauraav246/blob/main/Online/ProjectPart4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3913
# ##Discrete Mathematics
# ##Saurav Chaudhary
# ##Dr. Jacob

# %% [markdown]
# For this project I will pick up other items in my drawer rather than my previous example of drawing 3 coloured shocks from drawer ( Red , Green and Blue ) which would be Jeans, tshirts, gloves, cap, shoes, towels, tracks, sweater, jacket. This would make 10 events from the random items I selected.

# %%
possibleDrawings = ['Shocks','Jeans','Tshirts','Gloves','Cap','Shoes','Towels','Tracks','Sweater','Jacket']

# %% [markdown]
# Counting

# %% [markdown]
# For my project I have 10 examples so there are 10 possible outcomes in random picks, so the outcome be $10^{10}$
#
# $$ 10*10*10\dots *10 = 10^{10} $$

# %%
10**10
# Out:
# 10000000000

# %% [markdown]
# Here, lets suppose there are 20 possible outcomes everytime ignoring the order. Drawing random items 10 times will still result in 10 events every time we draw.

# %%
import math

math.factorial(20)/(math.factorial(10)*math.factorial(10))
# Out:
# 184756.0

# %% [markdown]
# For 8 random picks

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(possibleDrawings,8)))
# Out:
# [('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Jeans'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Tshirts'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Gloves'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Cap'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shoes'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Towels'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Tracks'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Sweater'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Jacket'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Jeans', 'Jeans'), ('Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Shocks', 'Jeans', 'Tshirts'), ('Shocks', 'Shocks
# ...

# %% [markdown]
# The Drawing results in huge series.

# %%
len(list(combinations_with_replacement(possibleDrawings,10)))
# Out:
# 92378

# %% [markdown]
# ## Without Replacing

# %%
print(math.factorial(10))
# Out:
# 3628800

# %%
math.factorial(10)/(math.factorial(0)*math.factorial(10))
# Out:
# 1.0

# %%
from itertools import combinations
print(list(combinations(possibleDrawings,8)))
# Out:
# [('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Towels', 'Tracks'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Towels', 'Sweater'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Towels', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Tracks', 'Sweater'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Tracks', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Shoes', 'Sweater', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Towels', 'Tracks', 'Sweater'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Towels', 'Tracks', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Towels', 'Sweater', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Cap', 'Tracks', 'Sweater', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Shoes', 'Towels', 'Tracks', 'Sweater'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Shoes', 'Towels', 'Tracks', 'Jacket'), ('Shocks', 'Jeans', 'Tshirts', 'Gloves', 'Sh
# ...

# %% [markdown]
# ##For Bionomial Expression (5th Order)
# Now The 5th order for bionomial expression

# %% [markdown]
#
# ##=9C5*(-3)^4
# ##=126*81
# ##=10206

# %% [markdown]
# The project demonstrate the outcomes of possible events results in huge number of series. It's difficult than other projects and confusing as well but I'm satisfied with my results. The outcome were huge I doubt if it's possible to do it by hands.
