# %% [markdown]
# <a href="https://colab.research.google.com/github/Saauraav246/Saauraav246/blob/main/Online/ProjectPart5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #5 : CPSMA 3913
# # Discrete Mathematics
#
# ## Structures
#
# ## Saurav Chaudhary [270090]

# %% [markdown]
# ## 1 Graphs and Trees

# %% [markdown]
# ##For the project, I decided to choose movies and their sequels for Marvel Studios.
#
# ![images.png](data:image/png;base64,...)

# %%
# !pip install anytree
# Out:
# ...
#      |████████████████████████████████| 41 kB 328 kB/s
# ...

# %%
from anytree import Node, RenderTree
from anytree.exporter import DotExporter
from IPython.display import display, Image
MS = Node("MARVEL STUDIOS") #root
BW =Node("BLACK WIDOW",parent=MS)
HK =Node("HULK",parent=MS)
SS = Node("SPIDERMAN SEQUELS", parent=MS)
IM= Node("IRONMAN SEQUELS", parent=MS)
TH = Node("THOR SEQUELS", parent=MS)
BP = Node("BLACK PANTHER", parent=MS)
SS1=Node("SPIDERMAN: NO WAY HOME",parent=SS)
SS2=Node("SPIDERMAN: FAR FROM HOME",parent=SS)
SS3=Node("SPIDERMAN:HOMECOMING",parent=SS)
IM1=Node("IRONMAN",parent=IM)
IM2=Node("IRONMAN:2",parent=IM)
IM3=Node("IRONMAN:3",parent=IM)
TH1=Node("THOR:RAGNAROK",parent=TH)
TH2=Node("THOR:DARKWORLD",parent=TH)
BP1=Node("WAKANDA FOREVER",parent=BP)

DotExporter(MS).to_picture("MS.png")
display(Image("MS.png"))

# %% [markdown]
# I choose to list out my favorite movies and their sequels from Marvel Studios. There are many movies from Marvel Studios and have numerous characters but here I will demonstrate a glance at a few of the characters. And there are a lot of movie sequels made after the name of the character which is kind of impossible here thats why I tried to make it small.
#
# There are 16 vertices including the root vertex and 15 edges altogether. There is no cyclical representation as it just follows a straight tree diagram but, I could have made a cycle by adding Avengers at the end where all the characters mentioned would connect to the avengers as in the movie and they would probably make the whole graph look like a mess.
#
# Overall, I really enjoyed this project of telling Marvel Studios movies and their sequels with a diagram.
